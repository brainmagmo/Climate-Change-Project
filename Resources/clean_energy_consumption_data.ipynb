# %%
import pandas as pd
import numpy as np
import requests
import json
from pprint import pprint

# %%
energy_consumption_data = pd.read_csv("energy consumption by country.csv")
energy_consumption_data.head()
# Out:
#                  Location         1986         1987         1988         1989  \
# 0                   World  324.5344016  334.5932663  347.6354523  352.3576472
# 1             Afghanistan  0.039111199  0.063065158  0.111220787  0.109364539
# 2                 Albania  0.166075365  0.166640543  0.168590876  0.160340585
# 3                 Algeria  1.073661264  1.148639374  1.222947634   1.18021525
# 4          American Samoa  0.006716584  0.006973009  0.006778814  0.007806191
#
#           1990         1991         1992         1993         1994  ...  \
# 0  358.9595455  352.2644272  351.0744285  353.9732567  357.8829972  ...
# 1  0.108320341  0.047438198  0.031281766  0.031068733  0.030081109  ...
# 2  0.114845298  0.096323694  0.084191203  0.073833402  0.070178183  ...
# 3  1.212354841  1.354444964   1.30211942  1.197210337  1.233072137  ...
# 4  0.008210538  0.008210538  0.008445519  0.008216196  0.008003583  ...
#
# ...

# %%
#Remove NaN column, API row and years before 1986.
clean_data = energy_consumption_data.dropna(how='any')
clean_data.head(30)
# Out:
#                           Location         1986         1987         1988  \
# 0                            World  324.5344016  334.5932663  347.6354523
# 1                      Afghanistan  0.039111199  0.063065158  0.111220787
# 2                          Albania  0.166075365  0.166640543  0.168590876
# 3                          Algeria  1.073661264  1.148639374  1.222947634
# 4                   American Samoa  0.006716584  0.006973009  0.006778814
# 5                           Angola  0.072853256  0.075135479  0.077495249
# 6                       Antarctica  0.002763963  0.002763963   0.00298473
# 7              Antigua and Barbuda  0.004624394  0.005755917  0.005771311
# 8                        Argentina  1.904251569  1.953187266  1.966407569
# 9                          Armenia           --           --           --
# 10                           Aruba  0.001453868  0.001453868  0.005570153
# 11                       Australia  3.237098549  3.346957902  3.471024553
# ...

# %%
clean_data.to_csv("../Cleaned Data/clean_energy_consumption_data.csv", index=True, header=True)
