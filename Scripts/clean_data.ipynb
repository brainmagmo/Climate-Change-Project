# %%
# Dependencies and setup
import pandas as pd
import pandas as pd
import numpy as np
import os

# %%
# Use os.join.path so any OS can run this code
file_path = os.path.join("..", "Resources", "population_density_by_country.csv")
world_pop = os.path.join("..", "Resources", "world population.csv")

# Read the csv into a data frame and display the first few rows
population_df = pd.read_csv(file_path, skiprows=4)
population_df.head()
# Out:
#   Country Name Country Code  \
# 0        Aruba          ABW
# 1  Afghanistan          AFG
# 2       Angola          AGO
# 3      Albania          ALB
# 4      Andorra          AND
#
#                                       Indicator Name Indicator Code  1960  \
# 0  Population density (people per sq. km of land ...    EN.POP.DNST   NaN
# 1  Population density (people per sq. km of land ...    EN.POP.DNST   NaN
# 2  Population density (people per sq. km of land ...    EN.POP.DNST   NaN
# 3  Population density (people per sq. km of land ...    EN.POP.DNST   NaN
# 4  Population density (people per sq. km of land ...    EN.POP.DNST   NaN
#
#          1961        1962        1963        1964        1965  ...  \
# 0  307.988889  312.361111  314.972222  316.844444  318.666667  ...
# 1   14.044987   14.323808   14.617537   14.926295   15.250314  ...
# 2    4.436891    4.498708    4.555593    4.600180    4.628676  ...
# 3   60.576642   62.456898   64.329234   66.209307   68.058066  ...
# ...

# %%
# We only want data for years 1986 - 2016 so we will remove any columns that aren't necessary 
population_df.drop(population_df.loc[:,"Indicator Name":"1985"], inplace=True, axis=1)

# Drop the remaining rows at the back end from 2017 to 2019
population_df.drop(population_df.loc[:,"2017":"Unnamed: 64"], inplace=True, axis=1)

# Display the first few rows
population_df.head()
# Out:
#   Country Name Country Code        1986        1987        1988        1989  \
# 0        Aruba          ABW  348.022222  343.516667  339.327778  339.066667
# 1  Afghanistan          AFG   17.976563   17.774920   17.795553   18.179820
# 2       Angola          AGO    8.277943    8.574035    8.877878    9.188078
# 3      Albania          ALB  110.315146  112.540328  114.683796  117.808139
# 4      Andorra          AND   98.972340  103.095745  107.306383  111.591489
#
#          1990        1991        1992        1993  ...        2007  \
# 0  345.272222  359.011111  379.083333  402.800000  ...  562.344444
# 1   19.012205   20.370396   22.187829   24.226638  ...   41.510486
# 2    9.503799    9.825059   10.152696   10.487727  ...   16.768559
# 3  119.946788  119.225912  118.505073  117.784197  ...  108.394781
# 4  115.976596  120.576596  125.293617  129.725532  ...  175.923404
#
#          2008        2009        2010        2011        2012        2013  \
# ...

# %%
# Find all the rows with missing data
missing_data = population_df[population_df.isnull().any(axis=1)]

# Display the missing data
missing_data.head()

# %%
# Drop the rows with missing data by the row index
population_df.drop(index=missing_data.index, inplace=True)

# Display the clean data
clean_data = population_df

# Save the clean data to a CSV
clean_data.to_csv("../Cleaned Data/population_density_clean.csv", index=False)

# Display the clean data
clean_data
# Out:
#      Country Name Country Code        1986        1987        1988  \
# 0           Aruba          ABW  348.022222  343.516667  339.327778
# 1     Afghanistan          AFG   17.976563   17.774920   17.795553
# 2          Angola          AGO    8.277943    8.574035    8.877878
# 3         Albania          ALB  110.315146  112.540328  114.683796
# 4         Andorra          AND   98.972340  103.095745  107.306383
# ..            ...          ...         ...         ...         ...
# 259        Kosovo          XKX  157.711032  161.017728  164.508129
# 260   Yemen, Rep.          YEM   18.828928   19.550435   20.324757
# 261  South Africa          ZAF   27.612092   28.273028   28.935124
# 262        Zambia          ZMB    9.614024    9.917859   10.221115
# 263      Zimbabwe          ZWE   23.782213   24.627641   25.459804
#
#            1989        1990        1991        1992        1993  ...  \
# 0    339.066667  345.272222  359.011111  379.083333  402.800000  ...
# ...

# %%
# Read the csv into a data frame and display the first few rows
world_pop_df = pd.read_csv(world_pop, skiprows=4)
world_pop_df.head()
# Out:
#   Country Name Country Code     Indicator Name Indicator Code       1960  \
# 0        Aruba          ABW  Population, total    SP.POP.TOTL    54211.0
# 1  Afghanistan          AFG  Population, total    SP.POP.TOTL  8996973.0
# 2       Angola          AGO  Population, total    SP.POP.TOTL  5454933.0
# 3      Albania          ALB  Population, total    SP.POP.TOTL  1608800.0
# 4      Andorra          AND  Population, total    SP.POP.TOTL    13411.0
#
#         1961       1962       1963       1964       1965  ...        2011  \
# 0    55438.0    56225.0    56695.0    57032.0    57360.0  ...    102046.0
# 1  9169410.0  9351441.0  9543205.0  9744781.0  9956320.0  ...  30117413.0
# 2  5531472.0  5608539.0  5679458.0  5735044.0  5770570.0  ...  24220661.0
# 3  1659800.0  1711319.0  1762621.0  1814135.0  1864791.0  ...   2905195.0
# 4    14375.0    15370.0    16412.0    17469.0    18549.0  ...     83747.0
#
#          2012        2013        2014        2015        2016        2017  \
# ...

# %%
# We only want data for years 1986 - 2016 so we will remove any columns that aren't necessary 
world_pop_df.drop(world_pop_df.loc[:,"Indicator Name":"1985"], inplace=True, axis=1)

# Drop the remaining rows at the back end from 2017 to 2019
world_pop_df.drop(world_pop_df.loc[:,"2017":"Unnamed: 64"], inplace=True, axis=1)

# Display the first few rows
world_pop_df.head()
# Out:
#   Country Name Country Code        1986        1987        1988        1989  \
# 0        Aruba          ABW     62644.0     61833.0     61079.0     61032.0
# 1  Afghanistan          AFG  11736179.0  11604534.0  11618005.0  11868877.0
# 2       Angola          AGO  10320111.0  10689250.0  11068050.0  11454777.0
# 3      Albania          ALB   3022635.0   3083605.0   3142336.0   3227943.0
# 4      Andorra          AND     46517.0     48455.0     50434.0     52448.0
#
#          1990        1991        1992        1993  ...        2007  \
# 0     62149.0     64622.0     68235.0     72504.0  ...    101222.0
# 1  12412308.0  13299017.0  14485546.0  15816603.0  ...  27100536.0
# 2  11848386.0  12248901.0  12657366.0  13075049.0  ...  20905363.0
# 3   3286542.0   3266790.0   3247039.0   3227287.0  ...   2970017.0
# 4     54509.0     56671.0     58888.0     60971.0  ...     82684.0
#
#          2008        2009        2010        2011        2012        2013  \
# ...

# %%
# Find all the rows with missing data
missing_data_world = world_pop_df[world_pop_df.isnull().any(axis=1)]

# Display the missing data
missing_data_world.head()
# Out:
#            Country Name Country Code       1986       1987       1988  \
# 67              Eritrea          ERI  2064794.0  2127422.0  2185605.0
# 108      Not classified          INX        NaN        NaN        NaN
# 125              Kuwait          KWT  1832310.0  1938909.0  2034857.0
# 194  West Bank and Gaza          PSE        NaN        NaN        NaN
# 212              Serbia          SRB        NaN        NaN        NaN
#
#           1989       1990       1991       1992       1993  ...       2007  \
# 67   2231141.0  2258653.0  2266358.0  2257596.0  2238626.0  ...  2996536.0
# 108        NaN        NaN        NaN        NaN        NaN  ...        NaN
# 125  2092777.0  2095344.0  2031296.0        NaN        NaN  ...  2504019.0
# 194        NaN  1978248.0  2068845.0  2163591.0  2262676.0  ...  3494496.0
# 212        NaN  7586000.0  7595636.0  7646424.0  7699307.0  ...  7381579.0
#
#           2008       2009       2010       2011       2012       2013  \
# ...

# %%
# Drop the rows with missing data by the row index
world_pop_df.drop(index=missing_data_world.index, inplace=True)

# Display the clean data
clean_data_world = world_pop_df

# Save the clean data to a CSV
clean_data_world.to_csv("../Cleaned Data/world_population_clean.csv", index=False)

# Display the clean data
clean_data_world
# Out:
#      Country Name Country Code        1986        1987        1988  \
# 0           Aruba          ABW     62644.0     61833.0     61079.0
# 1     Afghanistan          AFG  11736179.0  11604534.0  11618005.0
# 2          Angola          AGO  10320111.0  10689250.0  11068050.0
# 3         Albania          ALB   3022635.0   3083605.0   3142336.0
# 4         Andorra          AND     46517.0     48455.0     50434.0
# ..            ...          ...         ...         ...         ...
# 259        Kosovo          XKX   1717000.0   1753000.0   1791000.0
# 260   Yemen, Rep.          YEM   9941109.0  10322043.0  10730862.0
# 261  South Africa          ZAF  33495953.0  34297727.0  35100909.0
# 262        Zambia          ZMB   7146969.0   7372837.0   7598275.0
# 263      Zimbabwe          ZWE   9200149.0   9527203.0   9849125.0
#
#            1989        1990        1991        1992        1993  ...  \
# 0       61032.0     62149.0     64622.0     68235.0     72504.0  ...
# ...
