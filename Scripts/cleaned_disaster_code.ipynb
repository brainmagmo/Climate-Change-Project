# %%
# Dependencies and setup
import pandas as pd
import pandas as pd
import numpy as np
import os

# %%
disaster_df = pd.read_csv("../Cleaned Data/disasters.csv")
disaster_df.head()
# Out:
#    Year      Disaster Type     Country  ISO  Start Year  End Year  \
# 0  1900            Drought  Cabo Verde  CPV        1900      1900
# 1  1900            Drought       India  IND        1900      1900
# 2  1902         Earthquake   Guatemala  GTM        1902      1902
# 3  1902  Volcanic activity   Guatemala  GTM        1902      1902
# 4  1902  Volcanic activity   Guatemala  GTM        1902      1902
#
#    Total Deaths  Total Affected  Total Damages ('000 US$)
# 0       11000.0             NaN                       NaN
# 1     1250000.0             NaN                       NaN
# 2        2000.0             NaN                   25000.0
# 3        1000.0             NaN                       NaN
# 4        6000.0             NaN                       NaN

# %%
disaster_df = disaster_df.loc[(disaster_df["Year"] >= 1980) & 
                                (disaster_df["Year"] <= 2016), :]
disaster_df
# Out:
#        Year Disaster Type                             Country  ISO  \
# 2084   1980       Drought                       Côte d’Ivoire  CIV
# 2085   1980       Drought                               Ghana  GHA
# 2086   1980       Drought                               Benin  BEN
# 2087   1980       Drought                        Gambia (the)  GMB
# 2088   1980         Flood                         Afghanistan  AFG
# ...     ...           ...                                 ...  ...
# 15107  2016         Flood  Venezuela (Bolivarian Republic of)  VEN
# 15108  2016      Epidemic                            Viet Nam  VNM
# 15109  2016         Flood                            Viet Nam  VNM
# 15110  2016      Epidemic                             Vanuatu  VUT
# 15111  2016      Epidemic                         South Sudan  SSD
#
#        Start Year  End Year  Total Deaths  Total Affected  \
# 2084         1983      1983           NaN             NaN
# ...
