# %%
'''
Trevor Kleinstuber
'''

import pandas as pd
import os

# %%
# import data
file_path = os.path.join("..", "Resources", "emdat_public_2020_07_07_query_uid-X0uRMK.csv")
dis_df = pd.read_csv(file_path)
dis_df.head()
# Out:
#           Dis No  Year   Seq Disaster Group Disaster Subgroup  \
# 0  1900-9002-CPV  1900  9002        Natural    Climatological
# 1  1900-9001-IND  1900  9001        Natural    Climatological
# 2  1902-0012-GTM  1902    12        Natural       Geophysical
# 3  1902-0003-GTM  1902     3        Natural       Geophysical
# 4  1902-0010-GTM  1902    10        Natural       Geophysical
#
#        Disaster Type Disaster Subtype Disaster Subsubtype   Event Name  \
# 0            Drought          Drought                 NaN          NaN
# 1            Drought          Drought                 NaN          NaN
# 2         Earthquake  Ground movement                 NaN          NaN
# 3  Volcanic activity         Ash fall                 NaN  Santa Maria
# 4  Volcanic activity         Ash fall                 NaN  Santa Maria
#
#   Entry Criteria  ... End Day Total Deaths No Injured No Affected No Homeless  \
# 0            NaN  ...     NaN      11000.0        NaN         NaN         NaN
# 1            NaN  ...     NaN    1250000.0        NaN         NaN         NaN
# 2           Kill  ...    18.0       2000.0        NaN         NaN         NaN
# 3           Kill  ...     8.0       1000.0        NaN         NaN         NaN
# 4           Kill  ...    24.0       6000.0        NaN         NaN         NaN
#
#   Total Affected Reconstruction Costs ('000 US$) Insured Damages ('000 US$)  \
# 0            NaN                             NaN                        NaN
# 1            NaN                             NaN                        NaN
# 2            NaN                             NaN                        NaN
# 3            NaN                             NaN                        NaN
# 4            NaN                             NaN                        NaN
#
#   Total Damages ('000 US$)       CPI
# 0                      NaN  3.261389
# 1                      NaN  3.261389
# 2                  25000.0  3.391845
# 3                      NaN  3.391845
# 4                      NaN  3.391845
#
# [5 rows x 43 columns]

# %%
dis_df.columns
# Out:
# Index(['Dis No', 'Year', 'Seq', 'Disaster Group', 'Disaster Subgroup',
#        'Disaster Type', 'Disaster Subtype', 'Disaster Subsubtype',
#        'Event Name', 'Entry Criteria', 'Country', 'ISO', 'Region', 'Continent',
#        'Location', 'Origin', 'Associated Dis', 'Associated Dis2',
#        'OFDA Response', 'Appeal', 'Declaration', 'Aid Contribution',
#        'Dis Mag Value', 'Dis Mag Scale', 'Latitude', 'Longitude', 'Local Time',
#        'River Basin', 'Start Year', 'Start Month', 'Start Day', 'End Year',
#        'End Month', 'End Day', 'Total Deaths', 'No Injured', 'No Affected',
#        'No Homeless', 'Total Affected', 'Reconstruction Costs ('000 US$)',
#        'Insured Damages ('000 US$)', 'Total Damages ('000 US$)', 'CPI'],
#       dtype='object')

# %%
cut_df = dis_df[['Year',
       'Disaster Type','Country', 'ISO',
       'Start Year', 'End Year',
       'Total Deaths','Total Affected',
       'Total Damages (\'000 US$)']]
cut_df
# Out:
#        Year      Disaster Type                                 Country  ISO  \
# 0      1900            Drought                              Cabo Verde  CPV
# 1      1900            Drought                                   India  IND
# 2      1902         Earthquake                               Guatemala  GTM
# 3      1902  Volcanic activity                               Guatemala  GTM
# 4      1902  Volcanic activity                               Guatemala  GTM
# ...     ...                ...                                     ...  ...
# 15514  2020              Storm                                 Vanuatu  VUT
# 15515  2020              Flood                                   Yemen  YEM
# 15516  2020              Flood                                   Yemen  YEM
# 15517  2020              Flood  Congo (the Democratic Republic of the)  COD
# 15518  2020              Flood                             Timor-Leste  TLS
#
#        Start Year  End Year  Total Deaths  Total Affected  \
# 0            1900      1900       11000.0             NaN
# 1            1900      1900     1250000.0             NaN
# 2            1902      1902        2000.0             NaN
# 3            1902      1902        1000.0             NaN
# 4            1902      1902        6000.0             NaN
# ...           ...       ...           ...             ...
# 15514        2020      2020           4.0             NaN
# 15515        2020      2020          10.0        150030.0
# 15516        2020      2020          16.0           130.0
# 15517        2020      2020          52.0         92580.0
# 15518        2020      2020           NaN          9131.0
#
#        Total Damages ('000 US$)
# 0                           NaN
# 1                           NaN
# 2                       25000.0
# 3                           NaN
# 4                           NaN
# ...                         ...
# 15514                       NaN
# 15515                       NaN
# 15516                       NaN
# 15517                       NaN
# 15518                   20000.0
#
# [15519 rows x 9 columns]

# %%
cut_2 = cut_df[(cut_df['Start Year'] >= 1986) & (cut_df['End Year'] <= 2016)]

# %%
cut_df['Disaster Type'].unique()
# Out:
# array(['Drought', 'Earthquake', 'Volcanic activity',
#        'Mass movement (dry)', 'Storm', 'Flood', 'Epidemic', 'Landslide',
#        'Wildfire', 'Extreme temperature', 'Fog', 'Insect infestation',
#        'Impact', 'Animal accident'], dtype=object)

# %%
cut_2
# Out:
#        Year Disaster Type                             Country  ISO  \
# 2462   1986         Storm                           Argentina  ARG
# 2463   1986         Flood                           Argentina  ARG
# 2464   1986         Storm                           Australia  AUS
# 2465   1986         Storm                           Australia  AUS
# 2466   1986         Storm                           Australia  AUS
# ...     ...           ...                                 ...  ...
# 15106  2016         Flood      United States of America (the)  USA
# 15107  2016         Flood  Venezuela (Bolivarian Republic of)  VEN
# 15108  2016      Epidemic                            Viet Nam  VNM
# 15109  2016         Flood                            Viet Nam  VNM
# 15111  2016      Epidemic                         South Sudan  SSD
#
#        Start Year  End Year  Total Deaths  Total Affected  \
# 2462         1986      1986           1.0          1000.0
# 2463         1986      1986           3.0        204000.0
# 2464         1986      1986           NaN             NaN
# 2465         1986      1986           3.0          1012.0
# 2466         1986      1986           NaN             NaN
# ...           ...       ...           ...             ...
# 15106        2016      2016           5.0             NaN
# 15107        2016      2016           NaN             NaN
# 15108        2016      2016          27.0         79204.0
# 15109        2016      2016          21.0        206340.0
# 15111        2016      2016          15.0             NaN
#
#        Total Damages ('000 US$)
# 2462                        NaN
# 2463                        NaN
# 2464                     5778.0
# 2465                    70000.0
# 2466                    51000.0
# ...                         ...
# 15106                 2300000.0
# 15107                       NaN
# 15108                       NaN
# 15109                   22000.0
# 15111                       NaN
#
# [10860 rows x 9 columns]

# %%
cut_df.to_csv('../Cleaned Data/disasters.csv',index = False,header=True)
