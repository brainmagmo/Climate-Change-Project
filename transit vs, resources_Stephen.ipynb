# %%
import os
import pandas as pd
import csv

# %%
transit_data = pd.read_csv("Cleaned Data/Passenger use by year.csv")
energy_data = pd.read_csv("Cleaned Data/clean_energy_consumption_data.csv")

# %%
transit_df = pd.DataFrame(transit_data)
energy_df= pd.DataFrame(energy_data)

# %%
transit_df
# Out:
#      COUNTRY Country       VARIABLE                  Variable  YEAR  Year  \
# 0        KOR   Korea  T-PASS-RD-TOT  Road passenger transport  2001  2001
# 1        KOR   Korea  T-PASS-RD-TOT  Road passenger transport  2002  2002
# 2        KOR   Korea  T-PASS-RD-TOT  Road passenger transport  2003  2003
# 3        KOR   Korea  T-PASS-RD-TOT  Road passenger transport  2004  2004
# 4        KOR   Korea  T-PASS-RD-TOT  Road passenger transport  2005  2005
# ...      ...     ...            ...                       ...   ...   ...
# 2606     CHL   Chile  T-PASS-RL-TOT  Rail passenger transport  2014  2014
# 2607     CHL   Chile  T-PASS-RL-TOT  Rail passenger transport  2015  2015
# 2608     CHL   Chile  T-PASS-RL-TOT  Rail passenger transport  2016  2016
# 2609     CHL   Chile  T-PASS-RL-TOT  Rail passenger transport  2017  2017
# 2610     CHL   Chile  T-PASS-RL-TOT  Rail passenger transport  2018  2018
#
#      Unit Code                  Unit  PowerCode Code PowerCode  \
# ...

# %%
energy_df
# Out:
#             Location         1986         1987         1988         1989  \
# 0              World  324.5344016  334.5932663  347.6354523  352.3576472
# 1        Afghanistan  0.039111199  0.063065158  0.111220787  0.109364539
# 2            Albania  0.166075365  0.166640543  0.168590876  0.160340585
# 3            Algeria  1.073661264  1.148639374  1.222947634   1.18021525
# 4     American Samoa  0.006716584  0.006973009  0.006778814  0.007806191
# ...              ...          ...          ...          ...          ...
# 1149     Wake Island            0            0            0            0
# 1150  Western Sahara            0            0            0            0
# 1151           Yemen            0            0            0            0
# 1152          Zambia   0.09076501  0.081980147  0.080546524  0.064865504
# 1153        Zimbabwe    0.0425037  0.029455262  0.031615066  0.040564523
#
#              1990         1991         1992         1993         1994  ...  \
# ...
